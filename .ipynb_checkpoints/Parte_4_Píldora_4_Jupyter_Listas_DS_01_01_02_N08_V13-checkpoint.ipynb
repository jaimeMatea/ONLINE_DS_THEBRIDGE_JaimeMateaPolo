# %% [markdown]
# <img src = "./img/TheBridge_logo_RGB_color.jpg" width = 500><img src = "./img/python.jpg" width = 500>

# %% [markdown]
# # Python Basics I

# %% [markdown]
# ## Contenidos

# %% [markdown]
# * [Listas
# ](#Listas
# )

# %% [markdown]
# ## Listas
# [al indice](#Contenidos)
# Se trata de otro de los tipos de datos de Python más usados. Dentro de las colecciones, que veremos más adelante, la lista es la colección que normalmente se le da más uso. **Nos permiten almacenar conjuntos de variables u objetos**, y son elementos de lo más versátiles puesto que podemos almacenar objetos de distintos tipos, modificarlos, eliminarlos, meter listas dentro de listas... Sus dos caractrísticas principales son:
# * **Mutables**: una vez se ha creado la lista, se puede modificar
# * **Ordenada**: Los elementos tienen un cierto orden, lo que nos permite acceder al elemento que queramos teniendo en cuenta tal orden
#
# En cuanto a su sintaxis, cuando declaremos la lista simplemente hay que separar cada elemento con comas, y rodearlo todo con corchetes.

# %%
#Lista de números
numeros=[1,3,5,6]
print(numeros,type(numeros))
# Out:
# [1, 3, 5, 6] <class 'list'>

# %%
#Lista de strins
strings=["esto","es","una","lista"]
print(strings)

#Lista booleanos
booleanos=[True,False,not False,True or False]
print(booleanos)
# Out:
# ['esto', 'es', 'una', 'lista']
# [True, False, True, True]

# %%
#Lista de tipos mezclados
mix=["hola",12,True,-3.5]
print(mix)

#Listas dentro de listas
listas=["hola",21,23,[-3,"adios"]]
print(listas)
len(listas)
# Out:
# ['hola', 12, True, -3.5]
# ['hola', 21, 23, [-3, 'adios']]
# 4

# %%
concatenacion=mix+listas
print(concatenacion,type(concatenacion))
# Out:
# ['hola', 12, True, -3.5, 'hola', 21, 23, [-3, 'adios']] <class 'list'>

# %% [markdown]
# **NOTA**: ¿Ves por qué los decimales en Python siempre van con puntos y no con comas? Con las colecciones el intérprete de Python se volvería loco.
#
# Podemos ver tambien el tipo de la lista

# %%
type(mix)
# Out:
# list

# %% [markdown]
# Calcular la longitud de la misma mediante el método *built-in* ya visto: `len()`

# %%
len(mix)
# Out:
# 4

# %% [markdown]
# Accedemos a los elemenos de la lista mediante corchetes `[]`
#
# **Importante**. El primer elemento es el 0

# %%
lista_ejemplo=["hola",3,2,"patata"]
print(lista_ejemplo[0])
print(lista_ejemplo[-1])
print(lista_ejemplo[-2])
print(lista_ejemplo[7])
# Out:
# hola
# patata
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 5
#       1 lista_ejemplo=["hola",3,2,"patata"]
#       2 print(lista_ejemplo[0])
#       3 print(lista_ejemplo[-1])
#       4 print(lista_ejemplo[-2])
# ----> 5 print(lista_ejemplo[7])
#
# IndexError: list index out of range

# %% [markdown]
# ### Metodos en Listas
# Para el tipo de objeto lista, también hay una serie de métodos catacterísticos que nos permiten operar con ellas: añadir valores, quitarlos, indexado, filtrado, etc... En [este enlace](https://www.w3schools.com/python/python_ref_list.asp) puedes encontrar todos los métodos que podrás usar con listas.

# %%
asignaturas=["fisica","quimica","mates","lengua"]

#Añadir un elemento al final de una lista
asignaturas.append("filo")
print(asignaturas)

#Añadir elementos en una posicion determinada (a partir de su indice)
asignaturas.insert(1,"literatura")
print(asignaturas)

#Quitar un elemento a partir de su indice
asignaturas.pop(1)
print(asignaturas)

#Quitar un elemento por su valor
asignaturas.remove("filo")
print(asignaturas)

#Ordenar la lista, por orden alfabetico
asignaturas.sort()
print(asignaturas)

#Quitar todos los elementos
asignaturas.clear()
print(asignaturas)
# Out:
# ['fisica', 'quimica', 'mates', 'lengua', 'filo']
# ['fisica', 'literatura', 'quimica', 'mates', 'lengua', 'filo']
# ['fisica', 'quimica', 'mates', 'lengua', 'filo']
# ['fisica', 'quimica', 'mates', 'lengua']
# ['fisica', 'lengua', 'mates', 'quimica']
# []
