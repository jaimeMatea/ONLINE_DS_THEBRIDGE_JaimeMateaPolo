# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
for i in ejer_2:
    num=i**2
    print(num)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]
def duplicados(duplicado):
    indices=[]
    for indice,elemento in enumerate(ejer_3):
        if elemento==duplicado:
            indices.append(indice)
    print("La palabra",duplicado,"se encuentra en los indices",indices)

duplicados("un")
duplicados("es")
duplicados("binario")
# Out:
# La palabra un se encuentra en los indices [7]
# La palabra es se encuentra en los indices [3, 13]
# La palabra binario se encuentra en los indices [2, 15]

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
#Parte 1
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
cont=0
for i in ejer_9:
    if i==3:
        cont+=1
print("Se repite",cont,"veces")
# Out:
# Se repite 7 veces

# %%
#Parte 2
ejer_9_lista=list(ejer_9)
lista_nueva=[]
for i in ejer_9_lista:
    if i>=5 and i<10:
        lista_nueva.append(i)
tupla_nueva=tuple(lista_nueva)
print(tupla_nueva)
# Out:
# (5, 7, 9, 6, 7)

# %%
#Parte 3
ejer_3_tupla=list(ejer_3)
cont=0
for i in ejer_3_tupla:
    cont+=1
print(cont)
# Out:
# 16

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
if 60 in ejer_9:
    print("El número 60 está en la tupla")
else:
    print("El número 60 no está en la tupla")
# Out:
# El número 60 no está en la tupla

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
#Parte 1
ejer_9_lista=list(ejer_9)
print(ejer_9_lista)

ejer_9_set=set(ejer_9)
print(ejer_9_set)

ejer_9_dict={}
for indice,elemento in enumerate(ejer_9):
    ejer_9_dict[indice]=elemento
print(ejer_9_dict)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
resultado=1
for valor in ejer_6.values():
    resultado=resultado*valor

print(resultado)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
libreria=[
    {"titulo":"Teo va al parque","autor":"Teo","idioma original":"inglés","año de publicación":2000},
    {"titulo":"El Quijote","autor":"Cervantes","idioma original":"español","año de publicación":1605},
    {"titulo":"Hamlet","autor":"Shakespeare","idioma original":"inglés","año de publicación":1603},
    {"titulo":"Crimen y castigo","autor":"Dostoievsky","idioma original":"ruso","año de publicación":1867}
]
print(libreria)
# Out:
# [{'titulo': 'Teo va al parque', 'autor': 'Teo', 'idioma original': 'inglés', 'año de publicación': 2000}, {'titulo': 'El Quijote', 'autor': 'Cervantes', 'idioma original': 'español', 'año de publicación': 1605}, {'titulo': 'Hamlet', 'autor': 'Shakespeare', 'idioma original': 'inglés', 'año de publicación': 1603}, {'titulo': 'Crimen y castigo', 'autor': 'Dostoievsky', 'idioma original': 'ruso', 'año de publicación': 1867}]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
for i in libreria:
    i["idioma original"]="esperanto"
print(libreria)
# Out:
# [{'titulo': 'Teo va al parque', 'autor': 'Teo', 'idioma original': 'esperanto', 'año de publicación': 2000}, {'titulo': 'El Quijote', 'autor': 'Cervantes', 'idioma original': 'esperanto', 'año de publicación': 1605}, {'titulo': 'Hamlet', 'autor': 'Shakespeare', 'idioma original': 'esperanto', 'año de publicación': 1603}, {'titulo': 'Crimen y castigo', 'autor': 'Dostoievsky', 'idioma original': 'esperanto', 'año de publicación': 1867}]

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Prueba el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
titulo = input("Introduce el título de un libro:")
encontrado = False

for i in libreria:
    if i["titulo"] == titulo:
        encontrado = True
        print("El libro se encuentra en la librería")
if encontrado == False:
    print("Ese no lo tengo, ¿mola?")
# Out:
# Introduce el título de un libro: La lluvia amarilla
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]
def duplicados(duplicado):
    indices=[]
    for indice,elemento in enumerate(ejer_3):
        if elemento==duplicado:
            indices.append(indice)
    print("La palabra",duplicado,"se encuentra en los indices",indices)

duplicados("un")
duplicados("es")
duplicados("binario")
# Out:
# La palabra un se encuentra en los indices [7]
# La palabra es se encuentra en los indices [3, 13]
# La palabra binario se encuentra en los indices [2, 15]

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
def encuentra_libro(libreria,titulo="ninguno"):
    encontrado = False
    
    for i in libreria:
        if i["titulo"] == titulo:
            encontrado = True
            print("El libro se encuentra en la librería")
    if encontrado == False:
        print("Ese no lo tengo, ¿mola?")

encuentra_libro(libreria,titulo="Harry Potter")
# Out:
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
direccion=input("Ingrese su email:")

def direccion_valida(direccion):
    for i in direccion:
        if i=="@":
            return "La dirección de correo es válida"
    return "La dirección de correo no es válida"

direccion_valida(direccion)
# Out:
# Ingrese su email: jaime@gmail.com
# 'La dirección de correo es válida'

# %% [markdown]
# ##### Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
dni=input("Introduce tu dni:")

def dni_valido(dni):
    palabra="TRWAGMYFPDXBNJZSQVHLCKE"

    num_str=dni[:-1]
    letra=dni[-1].upper()
    
    if len(num_str)!=7 and len(num_str)!=8:
        return False

    numero=int(num_str)
    
    if palabra[numero%23]==letra:
        return True

    return False

dni_valido(dni)
# Out:
# Introduce tu dni: 1234562e
# False
